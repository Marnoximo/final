# %%
import pandas as pd
import os
import numpy as np

pd.set_option('display.max_rows', 200)

class_csv_path = '/home/tien/Works/DH/final/data/PlantCLEF2017FinalPackage/map_list.csv'
media_csv_path = '/home/tien/Works/DH/final/data/PlantCLEF2017FinalPackage/final_master.csv'
vnc_csv_path = '/home/tien/Works/DH/final/project/modules/vncreature_crawler/vncreature_list.csv'
data_path = '/home/tien/Works/DH/final/data/PlantCLEF2017Train1EOL/data/'

unknown_species = ['chua', 'chua co ten' , 'no latin 1']
column_mapping = {
    'class': 'vnc_class',
    'name_vi': 'vnc_name',
    'species': 'vnc_species',
    'order': 'vnc_order',
    'url': 'vnc_url',
    'family': 'vnc_family',
}

def remove_unknown_species(species):
    if species.lower() in unknown_species:
        return False
    return True

def find_planclef_species(vnc_species, plc_species_list):
    for species in plc_species_list:
        if vnc_species.lower() in species.lower():
            return species        
    return np.nan

def count_train_media(class_id):
    dir_path = os.path.join(data_path, str(class_id))
#     print(dir_path)
    if not os.path.exists(dir_path):
        return -2
    
    return int(len([fn for fn in os.listdir(dir_path) if not fn.startswith('.')]))

# %%
class_df = pd.read_csv(class_csv_path)
print(class_df.info())

media_df = pd.read_csv(media_csv_path)
print(media_df.info())

vnc_df = pd.read_csv(vnc_csv_path)
print(vnc_csv_df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 7 columns):
# Unnamed: 0    10000 non-null int64
# Species       10000 non-null object
# Genus         10000 non-null object
# Family        10000 non-null object
# Content       0 non-null float64
# MediaId       10000 non-null int64
# ClassId       10000 non-null int64
# dtypes: float64(1), int64(3), object(3)
# memory usage: 547.0+ KB
# None
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1467831 entries, 0 to 1467830
# Data columns (total 7 columns):
# Unnamed: 0    1467831 non-null int64
# Species       1467831 non-null object
# Genus         1467831 non-null object
# Family        1467831 non-null object
# Content       24837 non-null object
# MediaId       1467831 non-null int64
# ClassId       1467831 non-null int64
# dtypes: int64(3), object(4)
# memory usage: 78.4+ MB
# None
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1603 entries, 0 to 1602
# Data columns (total 7 columns):
# Unnamed: 0    1603 non-null int64
# class         1493 non-null object
# family        1485 non-null object
# name_vi       1603 non-null object
# order         1494 non-null object
# species       1603 non-null object
# url           1603 non-null object
# dtypes: int64(1), object(6)
# memory usage: 87.7+ KB
# None

# %%
plc_species_list = class_df['Species'].values.tolist()

vnc_df = vnc_df[vnc_df['species'].apply(remove_unknown_species)]
vnc_df = vnc_df.drop_duplicates(subset='species')
vnc_df['plc_species'] = vnc_df['species'].apply(lambda x: find_planclef_species(x, plc_species_list))

# %%
found_vnc_df = vnc_df.iloc[:, 1:].dropna(subset=['plc_species'])
found_vnc_df.rename(columns=column_mapping, inplace=True)
found_vnc_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 109 entries, 21 to 1602
# Data columns (total 7 columns):
# vnc_class      109 non-null object
# vnc_family     108 non-null object
# vnc_name       109 non-null object
# vnc_order      109 non-null object
# vnc_species    109 non-null object
# vnc_url        109 non-null object
# plc_species    109 non-null object
# dtypes: object(7)
# memory usage: 6.8+ KB

# %%
required_class_df_columns = ['ClassId', 'Species', 'Genus', 'Family']
plc_vnc_df = found_vnc_df.merge(class_df[required_class_df_columns], left_on='plc_species', right_on='Species', how='left')
plc_vnc_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 109 entries, 0 to 108
# Data columns (total 11 columns):
# vnc_class      109 non-null object
# vnc_family     108 non-null object
# vnc_name       109 non-null object
# vnc_order      109 non-null object
# vnc_species    109 non-null object
# vnc_url        109 non-null object
# plc_species    109 non-null object
# ClassId        109 non-null int64
# Species        109 non-null object
# Genus          109 non-null object
# Family         109 non-null object
# dtypes: int64(1), object(10)
# memory usage: 10.2+ KB

# %%
plc_vnc_species_list = plc_vnc_df['Species'].values.tolist()
media_vnc_df = media_df[media_df['Species'].isin(plc_vnc_species_list)]
media_vnc_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 24597 entries, 603 to 1467827
# Data columns (total 7 columns):
# Unnamed: 0    24597 non-null int64
# Species       24597 non-null object
# Genus         24597 non-null object
# Family        24597 non-null object
# Content       1058 non-null object
# MediaId       24597 non-null int64
# ClassId       24597 non-null int64
# dtypes: int64(3), object(4)
# memory usage: 1.5+ MB

# %%
countBySpc_media_vnc_df = media_vnc_df.groupby(by=['Species']).count()
countBySpc_media_vnc_df
# Out:
#                                                  Unnamed: 0  Genus  Family  \
# Species
# Abies delavayi Franch.                                  156    156     156
# Abutilon indicum (L.) Sweet                             175    175     175
# Achillea millefolium L.                                1786   1786    1786
# Achyranthes aspera L.                                   234    234     234
# Aglaia odorata Lour.                                    161    161     161
# Albizia chinensis (Osbeck) Merr.                        163    163     163
# Amorphophallus paeoniifolius (Dennst.) Nicolson         237    237     237
# Annona glabra L.                                        233    233     233
# Annona squamosa L.                                      180    180     180
# Anthogonium gracile Wall. ex Lindl.                     134    134     134
# Antidesma bunius (L.) Spreng.                           316    316     316
# Appendicula reflexa Blume                                86     86      86
# Artocarpus heterophyllus Lam.                           174    174     174
# Aucuba japonica Thunb.                                  249    249     249
# Avicennia marina (Forssk.) Vierh.                       217    217     217
# Barringtonia asiatica (L.) Kurz                         201    201     201
# Bauhinia purpurea L.                                    161    161     161
# Bauhinia variegata L.                                   219    219     219
# Bixa orellana L.                                        284    284     284
# Bombax ceiba L.                                         201    201     201
# Bruguiera sexangula (Lour.) Poir.                       162    162     162
# Bulbophyllum flabellum-veneris (J.Koenig) Aver.         160    160     160
# Caesalpinia sappan L.                                   163    163     163
# Calanthe triplicata (Willemet) Ames                     174    174     174
# Calophyllum inophyllum L.                               246    246     246
# Calotropis gigantea (L.) Dryand.                        257    257     257
# Camellia sinensis (L.) Kuntze                           181    181     181
# Cannabis sativa L.                                      286    286     286
# Carissa spinarum L.                                     176    176     176
# Cassia javanica L.                                      170    170     170
# Ceiba pentandra (L.) Gaertn.                            387    387     387
# Cerbera manghas L.                                      173    173     173
# Cheilocostus speciosus (J.Koenig) C.D.Specht            222    222     222
# Cleome viscosa L.                                       172    172     172
# Clerodendrum chinense (Osbeck) Mabb.                    171    171     171
# Combretum indicum (L.) DeFilipps                        186    186     186
# Congea tomentosa Roxb.                                  162    162     162
# Cordia myxa L.                                          159    159     159
# Cordia subcordata Lam.                                  197    197     197
# Costus tonkinensis Gagnep.                               77     77      77
# Couroupita guianensis Aubl.                             211    211     211
# Crotalaria retusa L.                                    233    233     233
# Crotalaria verrucosa L.                                 168    168     168
# Curculigo orchioides Gaertn.                            167    167     167
# Curcuma petiolata Roxb.                                 341    341     341
# Dendrobium anosmum Lindl.                               157    157     157
# Dendrobium chrysotoxum Lindl.                           156    156     156
# Dendrobium lindleyi Steud.                              155    155     155
# Dianella ensifolia (L.) DC.                             163    163     163
# Dischidia major (Vahl) Merr.                            162    162     162
# Drosera indica L.                                       166    166     166
# Durio zibethinus L.                                     196    196     196
# Eucommia ulmoides Oliv.                                  16     16      16
# Ficus auriculata Lour.                                  157    157     157
# Ficus retusa L.                                         159    159     159
# Gloriosa superba L.                                     229    229     229
# Hibiscus mutabilis L.                                   230    230     230
# Holarrhena pubescens Wall. ex G.Don                     168    168     168
# Houttuynia cordata Thunb.                               173    173     173
# Hura crepitans L.                                       269    269     269
# Hydnophytum formicarum Jack                             157    157     157
# Jasminum sambac (L.) Aiton                              159    159     159
# Kaempferia angustifolia Roscoe                          125    125     125
# Kaempferia galanga L.                                   177    177     177
# Koelreuteria paniculata Laxm.                           255    255     255
# Leonurus japonicus Houtt.                               160    160     160
# Liquidambar formosana Hance                             158    158     158
# Liriodendron chinense (Hemsl.) Sarg.                    156    156     156
# Lumnitzera racemosa Willd.                              156    156     156
# Magnolia grandiflora L.                                 605    605     605
# Melia azedarach L.                                      411    411     411
# Melochia corchorifolia L.                               168    168     168
# Melochia umbellata (Houtt.) Stapf                        91     91      91
# Mesua ferrea L.                                         170    170     170
# Moringa oleifera Lam.                                   188    188     188
# Murraya paniculata (L.) Jack                            180    180     180
# Paraderris elliptica (Wall.) Adema                       61     61      61
# Paris polyphylla Sm.                                    176    176     176
# Phaius tankervilleae (Banks) Blume                      181    181     181
# Phyllanthus acidus (L.) Skeels                          170    170     170
# Phyllanthus emblica L.                                  154    154     154
# Phyllanthus reticulatus Poir.                           160    160     160
# Phyllostachys nigra (Lodd. ex Lindl.) Munro             172    172     172
# Pithecellobium dulce (Roxb.) Benth.                     253    253     253
# Pseudosasa japonica (Steud.) Makino                     163    163     163
# Psilotum nudum (L.) P. Beauv.                           199    199     199
# Punica granatum L.                                      468    468     468
# Rauvolfia vomitoria Afzel.                              169    169     169
# Reynoutria japonica Houtt.                             1036   1036    1036
# Rhizophora mucronata Lam.                               183    183     183
# Rhodomyrtus tomentosa (Aiton) Hassk.                    178    178     178
# Ricinus communis L.                                    1070   1070    1070
# Rubia cordifolia L.                                     158    158     158
# Sedum sarmentosum Bunge                                 164    164     164
# Sesbania grandiflora (L.) Pers.                         184    184     184
# Sesuvium portulacastrum (L.) L.                         266    266     266
# Spathoglottis plicata Blume                             220    220     220
# Symphytum officinale L.                                 276    276     276
# Syzygium cumini (L.) Skeels                             198    198     198
# Syzygium jambos (L.) Alston                             235    235     235
# Tacca integrifolia Ker Gawl.                            182    182     182
# Tacca leontopetaloides (L.) Kuntze                      254    254     254
# Taiwania cryptomerioides Hayata                         181    181     181
# Tamarindus indica L.                                    298    298     298
# Telosma cordata (Burm. f.) Merr.                        155    155     155
# Urena lobata L.                                         241    241     241
# Vernicia montana Lour.                                  156    156     156
# Vitex trifolia L.                                       172    172     172
# Waltheria tomentosa H. St. John                          24     24      24
#
#                                                  Content  MediaId  ClassId
# Species
# Abies delavayi Franch.                                 0      156      156
# Abutilon indicum (L.) Sweet                            0      175      175
# Achillea millefolium L.                              255     1786     1786
# Achyranthes aspera L.                                  5      234      234
# Aglaia odorata Lour.                                   0      161      161
# Albizia chinensis (Osbeck) Merr.                       0      163      163
# Amorphophallus paeoniifolius (Dennst.) Nicolson        1      237      237
# Annona glabra L.                                       0      233      233
# Annona squamosa L.                                     0      180      180
# Anthogonium gracile Wall. ex Lindl.                    0      134      134
# Antidesma bunius (L.) Spreng.                          0      316      316
# Appendicula reflexa Blume                              0       86       86
# Artocarpus heterophyllus Lam.                          0      174      174
# Aucuba japonica Thunb.                                88      249      249
# Avicennia marina (Forssk.) Vierh.                      0      217      217
# Barringtonia asiatica (L.) Kurz                        0      201      201
# Bauhinia purpurea L.                                   0      161      161
# Bauhinia variegata L.                                 28      219      219
# Bixa orellana L.                                       0      284      284
# Bombax ceiba L.                                        0      201      201
# Bruguiera sexangula (Lour.) Poir.                      0      162      162
# Bulbophyllum flabellum-veneris (J.Koenig) Aver.        0      160      160
# Caesalpinia sappan L.                                  0      163      163
# Calanthe triplicata (Willemet) Ames                    0      174      174
# Calophyllum inophyllum L.                              0      246      246
# Calotropis gigantea (L.) Dryand.                       0      257      257
# Camellia sinensis (L.) Kuntze                          0      181      181
# Cannabis sativa L.                                    31      286      286
# Carissa spinarum L.                                    0      176      176
# Cassia javanica L.                                     0      170      170
# Ceiba pentandra (L.) Gaertn.                           1      387      387
# Cerbera manghas L.                                     0      173      173
# Cheilocostus speciosus (J.Koenig) C.D.Specht           0      222      222
# Cleome viscosa L.                                      3      172      172
# Clerodendrum chinense (Osbeck) Mabb.                   0      171      171
# Combretum indicum (L.) DeFilipps                       0      186      186
# Congea tomentosa Roxb.                                 0      162      162
# Cordia myxa L.                                         0      159      159
# Cordia subcordata Lam.                                 0      197      197
# Costus tonkinensis Gagnep.                             0       77       77
# Couroupita guianensis Aubl.                            1      211      211
# Crotalaria retusa L.                                   6      233      233
# Crotalaria verrucosa L.                                0      168      168
# Curculigo orchioides Gaertn.                           0      167      167
# Curcuma petiolata Roxb.                                0      341      341
# Dendrobium anosmum Lindl.                              0      157      157
# Dendrobium chrysotoxum Lindl.                          0      156      156
# Dendrobium lindleyi Steud.                             0      155      155
# Dianella ensifolia (L.) DC.                            0      163      163
# Dischidia major (Vahl) Merr.                           0      162      162
# Drosera indica L.                                      0      166      166
# Durio zibethinus L.                                    0      196      196
# Eucommia ulmoides Oliv.                                0       16       16
# Ficus auriculata Lour.                                 0      157      157
# Ficus retusa L.                                        0      159      159
# Gloriosa superba L.                                    9      229      229
# Hibiscus mutabilis L.                                  0      230      230
# Holarrhena pubescens Wall. ex G.Don                    0      168      168
# Houttuynia cordata Thunb.                              1      173      173
# Hura crepitans L.                                      0      269      269
# Hydnophytum formicarum Jack                            0      157      157
# Jasminum sambac (L.) Aiton                             0      159      159
# Kaempferia angustifolia Roscoe                         0      125      125
# Kaempferia galanga L.                                  0      177      177
# Koelreuteria paniculata Laxm.                         44      255      255
# Leonurus japonicus Houtt.                              0      160      160
# Liquidambar formosana Hance                            0      158      158
# Liriodendron chinense (Hemsl.) Sarg.                   0      156      156
# Lumnitzera racemosa Willd.                             0      156      156
# Magnolia grandiflora L.                              127      605      605
# Melia azedarach L.                                    39      411      411
# Melochia corchorifolia L.                              0      168      168
# Melochia umbellata (Houtt.) Stapf                      0       91       91
# Mesua ferrea L.                                        0      170      170
# Moringa oleifera Lam.                                  0      188      188
# Murraya paniculata (L.) Jack                           0      180      180
# Paraderris elliptica (Wall.) Adema                     0       61       61
# Paris polyphylla Sm.                                   0      176      176
# Phaius tankervilleae (Banks) Blume                     0      181      181
# Phyllanthus acidus (L.) Skeels                         0      170      170
# Phyllanthus emblica L.                                 0      154      154
# Phyllanthus reticulatus Poir.                          0      160      160
# Phyllostachys nigra (Lodd. ex Lindl.) Munro            3      172      172
# Pithecellobium dulce (Roxb.) Benth.                    4      253      253
# Pseudosasa japonica (Steud.) Makino                    0      163      163
# Psilotum nudum (L.) P. Beauv.                          0      199      199
# Punica granatum L.                                   144      468      468
# Rauvolfia vomitoria Afzel.                             0      169      169
# Reynoutria japonica Houtt.                            64     1036     1036
# Rhizophora mucronata Lam.                              0      183      183
# Rhodomyrtus tomentosa (Aiton) Hassk.                   0      178      178
# Ricinus communis L.                                  122     1070     1070
# Rubia cordifolia L.                                    0      158      158
# Sedum sarmentosum Bunge                                0      164      164
# Sesbania grandiflora (L.) Pers.                        0      184      184
# Sesuvium portulacastrum (L.) L.                        0      266      266
# Spathoglottis plicata Blume                            7      220      220
# Symphytum officinale L.                               67      276      276
# Syzygium cumini (L.) Skeels                            2      198      198
# Syzygium jambos (L.) Alston                            0      235      235
# Tacca integrifolia Ker Gawl.                           0      182      182
# Tacca leontopetaloides (L.) Kuntze                     0      254      254
# Taiwania cryptomerioides Hayata                        0      181      181
# Tamarindus indica L.                                   6      298      298
# Telosma cordata (Burm. f.) Merr.                       0      155      155
# Urena lobata L.                                        0      241      241
# Vernicia montana Lour.                                 0      156      156
# Vitex trifolia L.                                      0      172      172
# Waltheria tomentosa H. St. John                        0       24       24

# %%
plc_vnc_df['num_train'] = plc_vnc_df['ClassId'].apply(count_train_media)
plc_vnc_df[['num_train', 'ClassId']]
# Out:
#      num_train  ClassId
# 0           38   235732
# 1           12   295430
# 2           22   127344
# 3           26   331071
# 4           20   331060
# 5           96   159448
# 6           38   285487
# 7           10   150598
# 8          122    42649
# 9           12   189727
# 10          32   132431
# 11          30    23991
# 12          24   159340
# 13         198    20080
# 14         144    13330
# 15          26   156130
# 16          30   118354
# 17          64   118024
# 18          14   197109
# 19          98     7582
# 20          32   191471
# 21        1542   273034
# 22          22   135355
# 23         100    45561
# 24          12   204128
# 25          14   203548
# 26          10    68783
# 27         138    60209
# 28          52   204515
# 29          30   250415
# 30          18   249477
# 31          48    68607
# 32          12   179443
# 33          10    24611
# 34         536   189825
# 35        2244    69841
# 36          40   312594
# 37         370   192311
# 38          90   210020
# 39         150     6834
# 40          10   328802
# 41          52   166321
# 42         110   195956
# 43          72   279720
# 44         244   189669
# 45           8   169423
# 46          80   169293
# 47          20   149264
# 48          12   218778
# 49          12   215648
# 50          68   239689
# 51          12   222135
# 52          12   222315
# 53          10   222842
# 54          86   310278
# 55          20   196021
# 56          12   215501
# 57          12    66892
# 58          14   106473
# 59          92   106379
# 60          40   203275
# 61          30    21737
# 62          22    20977
# 63          38    13423
# 64          60    67140
# 65          10   166252
# 66          94      421
# 67          28    20229
# 68         216   183345
# 69         110   180061
# 70           8   250675
# 71          20   167509
# 72          92    25900
# 73          28   148815
# 74          18   201567
# 75         118    68324
# 76          30   118022
# 77          48    43643
# 78          14    43537
# 79         170   330603
# 80          38   306054
# 81          12   212920
# 82          20   192010
# 83          14   251141
# 84          24   193990
# 85          62   109610
# 86          20   217001
# 87          10   144408
# 88          16   161935
# 89          56   192998
# 90          16     7572
# 91          42    20199
# 92          30   209462
# 93          24   182403
# 94           8   166834
# 95          26   107842
# 96        1368   133595
# 97          14   302396
# 98          38   320433
# 99          16   194458
# 100         56   209809
# 101         12   134119
# 102         20   267267
# 103         18   266453
# 104         12   251826
# 105         30    57609
# 106         14   285354
# 107        328   201993
# 108         12   194498

# %%
plc_vnc_df['num_train'].sum()
# Out:
# 11034

# %%
plc_vnc_df.to_csv('/home/tien/Works/DH/final/project/reports/plantclef_vncreature_join_list.csv')
